# %%
import matplotlib.pyplot as plt
import cv2
from pathlib import Path
import os
from PIL import *
import matplotlib.image as mpimg
import numpy as np
from keras.preprocessing import image
import json
import random
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.layers import Dense, Dropout, Flatten
from keras.applications.resnet50 import ResNet50
import keras
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU   
from keras import optimizers
from sklearn.metrics import classification_report

# import sys
# sys.stdout = open('log.txt','wt')

# %%
base_model = ResNet50(weights=None, include_top=True, input_shape=(587,587,3))
  #for layer in  base_model.layers[:10]:

# %%
base_model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 587, 587, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 593, 593, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 294, 294, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 294, 294, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 294, 294, 64) 0           bn_conv1[0][0]
# ...

# %%
x = base_model.get_layer('avg_pool').output
predictions = Dense(5, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 567, 567, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 573, 573, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 284, 284, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 284, 284, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 284, 284, 64) 0           bn_conv1[0][0]
# ...

# %%
model50 = ResNet50(weights=None, include_top=False, input_shape=(567,567,3))

# %%
model50.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            (None, 567, 567, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 573, 573, 3)  0           input_4[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 284, 284, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 284, 284, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 284, 284, 64) 0           bn_conv1[0][0]
# ...

# %%
for layer in model50.layers[:7]:
      layer.trainable = False
for layer in model50.layers[7:]:
  layer.trainable = True
for i, layer in enumerate(model50.layers):
   print(i, layer.name, layer.trainable)
# Out:
# 0 input_4 False
# 1 conv1_pad False
# 2 conv1 False
# 3 bn_conv1 False
# 4 activation_148 False
# 5 pool1_pad False
# 6 max_pooling2d_4 False
# 7 res2a_branch2a True
# 8 bn2a_branch2a True
# 9 activation_149 True
# 10 res2a_branch2b True
# 11 bn2a_branch2b True
# 12 activation_150 True
# 13 res2a_branch2c True
# 14 res2a_branch1 True
# 15 bn2a_branch2c True
# 16 bn2a_branch1 True
# 17 add_49 True
# 18 activation_151 True
# 19 res2b_branch2a True
# 20 bn2b_branch2a True
# 21 activation_152 True
# 22 res2b_branch2b True
# 23 bn2b_branch2b True
# 24 activation_153 True
# 25 res2b_branch2c True
# 26 bn2b_branch2c True
# 27 add_50 True
# 28 activation_154 True
# 29 res2c_branch2a True
# 30 bn2c_branch2a True
# 31 activation_155 True
# 32 res2c_branch2b True
# 33 bn2c_branch2b True
# 34 activation_156 True
# 35 res2c_branch2c True
# 36 bn2c_branch2c True
# 37 add_51 True
# 38 activation_157 True
# 39 res3a_branch2a True
# 40 bn3a_branch2a True
# 41 activation_158 True
# ...
